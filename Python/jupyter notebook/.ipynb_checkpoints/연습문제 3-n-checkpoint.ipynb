# %% [markdown]
# # 3-1

# %%
def is_odd(num):
    if num % 2 == 0:
        return False
    else:
        return True
    
print(is_odd(int(input())))
# Out:
# 7
# True

# %%
def plus(a, b):
    return(a + b)

def minus(a, b):
    return(a - b)


result1 = plus(5, 3)
result2 = minus(5, 3)
print(result1)
print(result2)
# Out:
# 8
# 2

# %% [markdown]
# # 3-2

# %%
def plus2(a):
    i = 0
    for j in range(1, a + 1):
        i = i + j
    return i

print(plus2(int(input())))
# Out:
# 5
# 15

# %%
def total(num):
    total = 0
    for i in range(1, num + 1):
        total = total + i
    return total
print(total(10))
# Out:
# 55

# %%
def total1(num):
    i=0
    for _ in range(1,num+1):
        i = i + _
    return i

print(total1(10))
# Out:
# 55

# %%
def calculator(nums):
    a=0
    for i in range(len(nums)):
        a = a + nums[i]  
        b = a / len(nums)
    return (a, b)

result = calculator([3, 7, 9, 11])
print(result)
# Out:
# (30, 7.5)

# %% [markdown]
# # 3-3

# %%
def diff_sum(a, b, c):
    A = a+b+c
    B = a**2 + b**2 + c**2
    return (B - A)

print(diff_sum(2, 2, 2))
print(diff_sum(3, 4, 5))
# Out:
# 6
# 38

# %%
def get_sequence(n):
    num = 0
    f = 0
    k = []
    for i in range(1,n+1):
        num = num+i
        k.append(num)
        
    for j in k:
        f= f+j
    return(f)
        
get_sequence(int(input()))
# Out:
# 3
# 10

# %%
text = ''

# 코드 작성
# 함수명 str_adder (가변 입력)

def str_adder(*word):
    global text
    for w in word:
        text += w

str_adder('1', '2', '3', '4')
print(text)
# Out:
# 1234

# %%
str_adder('1', '2', '3', '4') # → 1234
str_adder('p', 'y', 't', 'h', 'o', 'n') # → python
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-64de5f8a1924> in <module>
#       8
#       9
# ---> 10 str_adder('1', '2', '3', '4') # → 1234
#      11 str_adder('p', 'y', 't', 'h', 'o', 'n') # → python
#
# TypeError: str_adder() takes 1 positional argument but 4 were given
